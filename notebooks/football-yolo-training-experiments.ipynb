# %%
# !pip install ultralytics==8.3.40

# %% [markdown]
# ## Train YOLOv11 with existing 312 images (no preprocesing or augmentations)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hHAihDo4saJlnxOkV3hC")
project = rf.workspace("sm-p4e11").project("football-g1yzd")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-2 in yolov11:: 100%|██████████| 636/636 [00:00<00:00, 2858.85it/s]

# %%
# !yolo task=detect mode=train model=yolo11l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 49.0M/49.0M [00:00<00:00, 158MB/s]
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ## Train YOLOv11 with 693 images (no test dataset) (no preprocessing or augmentations)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hHAihDo4saJlnxOkV3hC")
project = rf.workspace("sm-p4e11").project("football-g1yzd")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-4 in yolov11:: 100%|██████████| 1398/1398 [00:00<00:00, 2773.20it/s]

# %%
# !yolo task=detect mode=train model=yolo11l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 49.0M/49.0M [00:00<00:00, 248MB/s]
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
version.deploy("yolo11l", "runs/detect/train", "weights/best.pt")
# Out:
# View the status of your deployment at: https://app.roboflow.com/sm-p4e11/football-g1yzd/4
# Share your model with the world at: https://universe.roboflow.com/sm-p4e11/football-g1yzd/model/4

# %% [markdown]
# ## Train yolo11 with overlapping and freekick tags dropped

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hHAihDo4saJlnxOkV3hC")
project = rf.workspace("sm-p4e11").project("football-g1yzd")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-5 in yolov11:: 100%|██████████| 1386/1386 [00:00<00:00, 2779.31it/s]

# %%
# !yolo task=detect mode=train model=yolo11l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 49.0M/49.0M [00:00<00:00, 430MB/s]
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ## Train yolov11 (Steven annotations only)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hHAihDo4saJlnxOkV3hC")
project = rf.workspace("sm-p4e11").project("football-g1yzd")
version = project.version(6)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-6 in yolov11:: 100%|██████████| 836/836 [00:00<00:00, 2916.96it/s]

# %%
# !yolo task=detect mode=train model=yolo11l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ## Train yolo11l model with preprocessing+augmentations added. No test dataset or overlapping/freekick tags

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hHAihDo4saJlnxOkV3hC")
project = rf.workspace("sm-p4e11").project("football-g1yzd")
version = project.version(7)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-7 in yolov11:: 100%|██████████| 3442/3442 [00:00<00:00, 3530.62it/s]

# %%
# !yolo task=detect mode=train model=yolo11l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ## Training with yolov11x

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 109M/109M [00:00<00:00, 140MB/s]
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
project.version(dataset.version).deploy(model_type="yolov11", model_path=f"{HOME}/runs/detect/train3/")
# Out:
# View the status of your deployment at: https://app.roboflow.com/sm-p4e11/football-g1yzd/7
# Share your model with the world at: https://universe.roboflow.com/sm-p4e11/football-g1yzd/model/7

# %% [markdown]
# ### Dataset v2

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="JmZqW6VIdo4eSeLHDsSR")
project = rf.workspace("m-nybmx").project("football-g1yzd-wjx7m")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 33.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-1 in yolov11:: 100%|██████████| 2336/2336 [00:00<00:00, 3658.45it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 109M/109M [00:00<00:00, 130MB/s]
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
import os
HOME = os.getcwd()

project.version(dataset.version).deploy(model_type="yolov11", model_path=f"{HOME}/runs/detect/train/")
# Out:
# View the status of your deployment at: https://app.roboflow.com/m-nybmx/football-g1yzd-wjx7m/1
# Share your model with the world at: https://universe.roboflow.com/m-nybmx/football-g1yzd-wjx7m/model/1

# %% [markdown]
# ### Train yolo11l with updated dataset (no preprocessing/augmentations)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Lg3ClikXhiqDxiTAVz8m")
project = rf.workspace("a-j0go6").project("football-g1yzd-oymqp")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 45.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-2 in yolov11:: 100%|██████████| 1398/1398 [00:00<00:00, 2842.79it/s]

# %%
# !yolo task=detect mode=train model=yolo11l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 49.0M/49.0M [00:00<00:00, 325MB/s]
# Ultralytics 8.3.71 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Dataset v2 - new augmentations

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="JmZqW6VIdo4eSeLHDsSR")
project = rf.workspace("m-nybmx").project("football-g1yzd-wjx7m")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.3.71 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
project.version(dataset.version).deploy(model_type="yolov11", model_path=f"{HOME}/runs/detect/train/")
# Out:
# View the status of your deployment at: https://app.roboflow.com/m-nybmx/football-g1yzd-wjx7m/2
# Share your model with the world at: https://universe.roboflow.com/m-nybmx/football-g1yzd-wjx7m/model/2
