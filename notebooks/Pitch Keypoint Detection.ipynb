# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.2 MB/s eta 0:00:00

# %%
# !pip install -q roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 48.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 129.6 MB/s eta 0:00:00

# %%
import torch
import random
import numpy as np

# %% [markdown]
# # Auto-orient preprocessing

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-field-detection-f07vi-pxjmn")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-field-detection-1 in yolov8:: 100%|██████████| 646/646 [00:00<00:00, 3164.14it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
random.seed(42)
torch.manual_seed(42)
np.random.seed(42)

# %%
# !yolo task=pose mode=train model=yolo11x-pose.pt data={dataset.location}/data.yaml batch=16 epochs=500 imgsz=640 mosaic=0.0
# Out:
# ...
# 100% 113M/113M [00:02<00:00, 39.8MB/s]
# Ultralytics 8.3.124 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Batch size = 8

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-field-detection-f07vi-pxjmn")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
random.seed(42)
torch.manual_seed(42)
np.random.seed(42)

# %%
# !yolo task=pose mode=train model=yolo11x-pose.pt data={dataset.location}/data.yaml batch=8 epochs=500 imgsz=640 mosaic=0.0
# Out:
# Ultralytics 8.3.124 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Batch size = 32

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-field-detection-f07vi-pxjmn")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
random.seed(42)
torch.manual_seed(42)
np.random.seed(42)

# %%
# !yolo task=pose mode=train model=yolo11x-pose.pt data={dataset.location}/data.yaml batch=16 epochs=500 imgsz=640 mosaic=0.0
# Out:
# Ultralytics 8.3.124 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Epochs = 100

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-field-detection-f07vi-pxjmn")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
random.seed(42)
torch.manual_seed(42)
np.random.seed(42)

# %%
# !yolo task=pose mode=train model=yolo11x-pose.pt data={dataset.location}/data.yaml batch=16 epochs=100 imgsz=640 mosaic=0.0
# Out:
# Ultralytics 8.3.124 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Epochs = 250

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-field-detection-f07vi-pxjmn")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
random.seed(42)
torch.manual_seed(42)
np.random.seed(42)

# %%
# !yolo task=pose mode=train model=yolo11x-pose.pt data={dataset.location}/data.yaml batch=16 epochs=250 imgsz=640 mosaic=0.0
# Out:
# Ultralytics 8.3.124 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...
