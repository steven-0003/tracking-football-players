# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 MB 37.3 MB/s eta 0:00:00

# %%
# !pip install -q roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 123.6 MB/s eta 0:00:00

# %% [markdown]
# # Training with original dataset (hflip, saturation, brightness augmentations)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-original")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-Original-1 in yolov11:: 100%|██████████| 1846/1846 [00:00<00:00, 3946.00it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 109M/109M [00:00<00:00, 257MB/s]
# Ultralytics 8.3.121 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Training with new dataset

# %% [markdown]
# # Hflip, Saturation, Brightness Augmentations

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-Updated-1 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 3883.07it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 109M/109M [00:00<00:00, 174MB/s]
# Ultralytics 8.3.122 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Hflip, Exposure, Noise Augmentations

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-Updated-2 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 3900.33it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Hflip, Hue, Noise Augmentations

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-Updated-3 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 3842.09it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Hflip, Hue, Saturation Augmentations

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-Updated-4 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 3888.86it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Hflip, Hue, Brightness Augmentations

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# ...
# Extracting Dataset Version Zip to Football-Updated-5 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 3964.48it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Hflip, Hue, Exposure Augmentations

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(6)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# ...
# Extracting Dataset Version Zip to Football-Updated-6 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 3947.65it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Hflip, Saturation, Exposure Augmentations

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(7)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# ...
# Extracting Dataset Version Zip to Football-Updated-7 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 3860.42it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Hflip, Brightness, Exposure Augmentations

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(8)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# ...
# Extracting Dataset Version Zip to Football-Updated-8 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 3927.84it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Hflip, Brightness, Noise Augmentations

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(9)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# ...
# Extracting Dataset Version Zip to Football-Updated-9 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 3870.39it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# # Hflip, Saturation, Noise Augmentations

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(10)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# ...
# Extracting Dataset Version Zip to Football-Updated-10 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 3868.28it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# #  Hflip, Saturation, Brightness

# %% [markdown]
# ## Mosaic augmentation turned off

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-Updated-1 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 4028.26it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 mosaic=0.0
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 109M/109M [00:02<00:00, 45.7MB/s]
# Ultralytics 8.3.123 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# ### Batch Size = 8

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 batch=8
# Out:
# Ultralytics 8.3.123 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Batch Size = 32

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-Updated-1 in yolov11:: 100%|██████████| 3774/3774 [00:00<00:00, 4042.92it/s]

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 batch=32
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 109M/109M [00:00<00:00, 157MB/s]
# Ultralytics 8.3.123 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Epochs = 150

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=150 imgsz=640
# Out:
# Ultralytics 8.3.123 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Epochs = 200

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=200 imgsz=640
# Out:
# Ultralytics 8.3.123 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Epochs = 250

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TNJHbqqCSSKgDRIV4vvk")
project = rf.workspace("steven-njsrz").project("football-updated-t7jp9")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=250 imgsz=640
# Out:
# Ultralytics 8.3.123 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...
